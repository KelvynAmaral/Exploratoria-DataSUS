# %% [markdown]
# <a href="https://colab.research.google.com/github/KelvynAmaral/dataSUS-analise-e-exploracao-de-dados/blob/main/Produ%C3%A7%C3%B5o_Hospitalar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Analisando dados de produção da Saúde

# %%
import pandas as pd

# %%
dados = pd.read_csv("/content/drive/MyDrive/PÓS DATA ANALYTICS/ARQUIVOS/AULA 1/datasus-ano-mes-processamentos-uf.csv",
                    encoding = "ISO-8859-1", skiprows=3, skipfooter=12, sep=";", thousands=".", decimal=",")
# Out:
# <ipython-input-17-c64f034ae465>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   dados = pd.read_csv("/content/drive/MyDrive/PÓS DATA ANALYTICS/ARQUIVOS/AULA 1/datasus-ano-mes-processamentos-uf.csv",

# %%
dados.head()
# Out:
#   Unidade da Federação      2008/Jan      2008/Fev      2008/Mar  \
# 0          11 Rondônia  1,388,528.39  2,931,283.42  1,541,682.52
# 1              12 Acre    902,416.00  1,497,206.26  1,794,028.48
# 2          13 Amazonas  4,735,529.42  7,118,990.57  8,196,635.49
# 3           14 Roraima    657,889.53    777,939.31    718,688.03
# 4              15 Pará 18,864,744.11 19,553,758.20 21,937,342.70
#
#        2008/Abr      2008/Mai      2008/Jun      2008/Jul      2008/Ago  \
# 0  1,525,314.96  1,645,953.84  1,406,150.68  3,065,279.01  3,231,494.61
# 1  1,730,469.42  1,819,443.92  1,828,496.00  2,511,754.59  2,089,107.14
# 2  8,259,378.42  7,831,399.90  8,477,273.62  9,368,858.72  9,352,532.70
# 3    839,994.39    862,347.96    832,440.66    996,693.09    894,271.18
# 4 20,842,829.69 23,249,952.88 23,240,687.56 24,002,223.56 23,341,218.03
#
#        2008/Set  ...      2023/Out      2023/Nov      2023/Dez      2024/Jan  \
# ...

# %%
dados.tail()
# Out:
#      Unidade da Federação      2008/Jan      2008/Fev      2008/Mar  \
# 22   43 Rio Grande do Sul 30,931,325.46 57,363,420.01 51,547,794.07
# 23  50 Mato Grosso do Sul  5,377,392.11  7,002,472.61  8,423,933.19
# 24         51 Mato Grosso  4,795,299.01  8,684,882.23  7,886,243.14
# 25               52 Goiás 15,310,637.29 22,258,668.68 21,442,515.75
# 26    53 Distrito Federal  4,745,919.19  7,632,480.67  9,647,203.26
#
#         2008/Abr      2008/Mai      2008/Jun      2008/Jul      2008/Ago  \
# 22 56,673,338.49 48,397,733.07 52,413,429.62 56,636,376.98 56,113,054.70
# 23  8,797,487.68  9,770,421.80 10,905,392.18 10,249,299.82  9,671,553.45
# 24  8,794,109.79  9,231,645.40 10,221,763.77  9,163,314.28  9,243,148.81
# 25 20,921,212.45 21,615,970.67 18,270,043.87 20,540,517.13 20,650,730.67
# 26 11,098,732.99 12,891,719.72 12,850,125.67 12,565,646.74 13,710,857.89
#
#         2008/Set  ...       2023/Out       2023/Nov       2023/Dez  \
# ...

# %%
dados.mean(numeric_only=True)
# Out:
# 2008/Jan      15,126,846.64
# 2008/Fev      22,710,158.12
# 2008/Mar      24,594,187.35
# 2008/Abr      25,431,957.83
# 2008/Mai      26,511,245.91
#                  ...
# 2024/Mar      70,797,784.92
# 2024/Abr      72,218,520.27
# 2024/Mai      72,584,793.40
# 2024/Jun      70,181,204.76
# Total      8,933,463,602.22
# Length: 198, dtype: float64

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Columns: 200 entries, Unidade da Federação to Total
# dtypes: float64(198), object(2)
# memory usage: 42.3+ KB

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %%
dados.mean(numeric_only=True)
# Out:
# 2008/Jan      15,126,846.64
# 2008/Fev      22,710,158.12
# 2008/Mar      24,594,187.35
# 2008/Abr      25,431,957.83
# 2008/Mai      26,511,245.91
#                  ...
# 2024/Mar      70,797,784.92
# 2024/Abr      72,218,520.27
# 2024/Mai      72,584,793.40
# 2024/Jun      70,181,204.76
# Total      8,933,463,602.22
# Length: 198, dtype: float64

# %%
coluna_mais_recente = dados.columns[-2]

# %%
dados_mais_recente = dados[[coluna_mais_recente]]

# %%
print(dados_mais_recente.head())
# Out:
#        2024/Jun
# 0  1,968,819.10
# 1  4,484,207.99
# 2 21,291,999.69
# 3  2,598,375.67
# 4 48,365,091.56

# %%
coluna_mais_recente2 = dados[[dados.columns[-2]]]

# %%
print(coluna_mais_recente2.head())
# Out:
#        2024/Jun
# 0  1,968,819.10
# 1  4,484,207.99
# 2 21,291,999.69
# 3  2,598,375.67
# 4 48,365,091.56

# %%
print(dados[[dados.columns[-2]]].mean(numeric_only=True))
# Out:
# 2024/Jun   70,181,204.76
# dtype: float64
